# %% [markdown]
# # Попытаемся что-то сделать, собственно #

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
import pathlib

DATA_DIR = pathlib.Path("../data/")
train_target = pd.read_csv(DATA_DIR.joinpath("pet_target_train.csv"), index_col="date", parse_dates=["date"])
test_target = pd.read_csv(DATA_DIR.joinpath("pet_test_timestamps.csv"), index_col="date", parse_dates=["date"])
daily = pd.read_csv(DATA_DIR.joinpath("pet_daily.csv"), index_col="date", parse_dates=["date"])
weekly = pd.read_csv(DATA_DIR.joinpath("pet_weekly.csv"), index_col="date", parse_dates=["date"])

# %% [markdown]
# # Все то, что внизу до заголовка "Тупая фигня" можно игнорировать, потому что это все неработающая хрень. А вот тупая фигня работает.

# %% [markdown]
# ## Feature generation ##

# %% [markdown]
# Так, ну это код из бейзлайна, тут ничего лучше не придумать - мы делаем признаки на каждый день.

# %%
dfts = daily.resample("D").mean()
wfts = weekly.resample("D").ffill()
fts = dfts.join(wfts)

# %% [markdown]
# Опять же, код из бейзлайна.

# %%
PERIODS = ["1D", "7D", "30D", "60D", "180D"]
AGGREGATES = ["mean", "median", "std", "max", "min"]

all_features = []

for period in PERIODS:
    for agg in AGGREGATES:
        if agg!="mean" and period=="1D":
            continue
        rolling_features = dfts.rolling(period).aggregate(agg)
        rolling_features.rename(lambda x: "_".join([x, period, agg]), axis=1, inplace=True)
        all_features.append(rolling_features[rolling_features.index.day==9])

# %%
all_features = pd.concat(all_features, axis=1)

all_features["prediction_date"] = (all_features.index
                                   + pd.TimedeltaIndex(all_features.index.days_in_month-8,
                                                       unit="D"))
final_fts = all_features.ffill()

# %%
data = train_target.join(final_fts.set_index("prediction_date"), how="outer")["2004-06":]
data.index.name = "date"
data.head()
# Out:
#                 pet  brent_close_1D_mean  brent_open_1D_mean  \
# date
# 2004-06-01   961.25                32.23               32.95
# 2004-07-01   962.00                35.29               34.75
# 2004-08-01  1053.75                37.05               37.60
# 2004-09-01  1180.00                37.05               37.60
# 2004-10-01  1240.00                42.22               40.25
#
#             brent_max_1D_mean  brent_min_1D_mean  USDCNY_close_1D_mean  \
# date
# 2004-06-01              33.14              32.15                8.2767
# 2004-07-01              35.44              34.43                8.2767
# 2004-08-01              37.80              37.00                8.2769
# 2004-09-01              37.80              37.00                8.2769
# 2004-10-01              42.30              40.10                8.2768
#
#             USDCNY_open_1D_mean  USDCNY_max_1D_mean  USDCNY_min_1D_mean  \
# date
# 2004-06-01               8.2767              8.2767              8.2767
# 2004-07-01               8.2767              8.2767              8.2767
# 2004-08-01               8.2769              8.2769              8.2769
# 2004-09-01               8.2769              8.2769              8.2769
# 2004-10-01               8.2768              8.2768              8.2768
#
#             brent_close_7D_mean  ...  USDCNY_max_180D_max  \
# date                             ...
# 2004-06-01              36.5450  ...               8.2774
# 2004-07-01              35.6740  ...               8.2774
# 2004-08-01              36.9820  ...               8.2774
# 2004-09-01              40.5225  ...               8.2774
# 2004-10-01              41.0440  ...               8.2774
#
#             USDCNY_min_180D_max  brent_close_180D_min  brent_open_180D_min  \
# date
# 2004-06-01               8.2774                 27.86                28.05
# 2004-07-01               8.2774                 28.83                28.94
# 2004-08-01               8.2774                 28.83                29.00
# 2004-09-01               8.2774                 30.07                29.65
# 2004-10-01               8.2774                 30.21                30.69
#
#             brent_max_180D_min  brent_min_180D_min  USDCNY_close_180D_min  \
# date
# 2004-06-01               28.43               27.68                 8.2767
# 2004-07-01               29.18               28.44                 8.2767
# 2004-08-01               29.18               28.44                 8.2766
# 2004-09-01               30.15               29.57                 8.2766
# 2004-10-01               30.92               29.95                 8.2766
#
#             USDCNY_open_180D_min  USDCNY_max_180D_min  USDCNY_min_180D_min
# date
# 2004-06-01                8.2767               8.2767               8.2767
# 2004-07-01                8.2767               8.2767               8.2767
# 2004-08-01                8.2766               8.2766               8.2766
# 2004-09-01                8.2766               8.2766               8.2766
# 2004-10-01                8.2766               8.2766               8.2766
#
# [5 rows x 169 columns]

# %% [markdown]
# Итак, теперь у нас есть датафрейм, на котором нам надо просто сделать регрессию. С ним особенно ничего не сделаешь, так что попробуем нагенерить всякой дичи.

# %%
df = data.copy()
cols = list(data.columns)
cols.remove('pet')
for i, col1 in enumerate(cols):
    for col2 in cols[i + 1:]:
        new_col = data[col1] * data[col2]
        df[col1 + '__' + col2] = new_col
df.head()
# Out:
#                 pet  brent_close_1D_mean  brent_open_1D_mean  \
# date
# 2004-06-01   961.25                32.23               32.95
# 2004-07-01   962.00                35.29               34.75
# 2004-08-01  1053.75                37.05               37.60
# 2004-09-01  1180.00                37.05               37.60
# 2004-10-01  1240.00                42.22               40.25
#
#             brent_max_1D_mean  brent_min_1D_mean  USDCNY_close_1D_mean  \
# date
# 2004-06-01              33.14              32.15                8.2767
# 2004-07-01              35.44              34.43                8.2767
# 2004-08-01              37.80              37.00                8.2769
# 2004-09-01              37.80              37.00                8.2769
# 2004-10-01              42.30              40.10                8.2768
#
#             USDCNY_open_1D_mean  USDCNY_max_1D_mean  USDCNY_min_1D_mean  \
# date
# 2004-06-01               8.2767              8.2767              8.2767
# 2004-07-01               8.2767              8.2767              8.2767
# 2004-08-01               8.2769              8.2769              8.2769
# 2004-09-01               8.2769              8.2769              8.2769
# 2004-10-01               8.2768              8.2768              8.2768
#
#             brent_close_7D_mean  ...  \
# date                             ...
# 2004-06-01              36.5450  ...
# 2004-07-01              35.6740  ...
# 2004-08-01              36.9820  ...
# 2004-09-01              40.5225  ...
# 2004-10-01              41.0440  ...
#
#             brent_min_180D_min__USDCNY_close_180D_min  \
# date
# 2004-06-01                                 229.099056
# 2004-07-01                                 235.389348
# 2004-08-01                                 235.386504
# 2004-09-01                                 244.739062
# 2004-10-01                                 247.884170
#
#             brent_min_180D_min__USDCNY_open_180D_min  \
# date
# 2004-06-01                                229.099056
# 2004-07-01                                235.389348
# 2004-08-01                                235.386504
# 2004-09-01                                244.739062
# 2004-10-01                                247.884170
#
#             brent_min_180D_min__USDCNY_max_180D_min  \
# date
# 2004-06-01                               229.099056
# 2004-07-01                               235.389348
# 2004-08-01                               235.386504
# 2004-09-01                               244.739062
# 2004-10-01                               247.884170
#
#             brent_min_180D_min__USDCNY_min_180D_min  \
# date
# 2004-06-01                               229.099056
# 2004-07-01                               235.389348
# 2004-08-01                               235.386504
# 2004-09-01                               244.739062
# 2004-10-01                               247.884170
#
#             USDCNY_close_180D_min__USDCNY_open_180D_min  \
# date
# 2004-06-01                                    68.503763
# 2004-07-01                                    68.503763
# 2004-08-01                                    68.502108
# 2004-09-01                                    68.502108
# 2004-10-01                                    68.502108
#
#             USDCNY_close_180D_min__USDCNY_max_180D_min  \
# date
# 2004-06-01                                   68.503763
# 2004-07-01                                   68.503763
# 2004-08-01                                   68.502108
# 2004-09-01                                   68.502108
# 2004-10-01                                   68.502108
#
#             USDCNY_close_180D_min__USDCNY_min_180D_min  \
# date
# 2004-06-01                                   68.503763
# 2004-07-01                                   68.503763
# 2004-08-01                                   68.502108
# 2004-09-01                                   68.502108
# 2004-10-01                                   68.502108
#
#             USDCNY_open_180D_min__USDCNY_max_180D_min  \
# date
# 2004-06-01                                  68.503763
# 2004-07-01                                  68.503763
# 2004-08-01                                  68.502108
# 2004-09-01                                  68.502108
# 2004-10-01                                  68.502108
#
#             USDCNY_open_180D_min__USDCNY_min_180D_min  \
# date
# 2004-06-01                                  68.503763
# 2004-07-01                                  68.503763
# 2004-08-01                                  68.502108
# 2004-09-01                                  68.502108
# 2004-10-01                                  68.502108
#
#             USDCNY_max_180D_min__USDCNY_min_180D_min
# date
# 2004-06-01                                 68.503763
# 2004-07-01                                 68.503763
# 2004-08-01                                 68.502108
# 2004-09-01                                 68.502108
# 2004-10-01                                 68.502108
#
# [5 rows x 14197 columns]

# %%
train = df[:'2015-12-01']

# %% [markdown]
# Теперь найдем корреляции всей этой фигни с таргетом.

# %%
from scipy.stats import pearsonr

corrs = {}
for col in train.columns:
    corrs[col] = abs(pearsonr(train[col], train_target['pet'])[0])

# %%
corrs = list(zip(corrs.values(), corrs.keys()))
corrs.sort(reverse=True)

# %%
corrs[:10]
# Out:
# [(1.0, 'pet'),
#  (0.768275266657408, 'brent_close_7D_min__USDCNY_open_180D_min'),
#  (0.768215603718349, 'brent_close_7D_min__USDCNY_min_180D_min'),
#  (0.7682122013718794, 'brent_close_7D_min__USDCNY_max_180D_min'),
#  (0.7681783423797799, 'brent_close_7D_min__USDCNY_close_180D_min'),
#  (0.7681778263627166, 'brent_close_7D_min__USDCNY_open_180D_median'),
#  (0.7681482608896524, 'brent_close_7D_min__USDCNY_max_180D_median'),
#  (0.7681244776707767, 'brent_close_7D_min__USDCNY_min_180D_median'),
#  (0.7681168558723362, 'brent_close_7D_min__USDCNY_close_180D_median'),
#  (0.767567623659583, 'brent_min_7D_min__USDCNY_open_180D_min')]

# %% [markdown]
# Заметим, что корреляции стали больше!

# %%
corrs.remove((1., 'pet'))
final_cols = [el[1] for el in corrs[:200]]

# %%
train = df[final_cols][:'2013']
val = df[final_cols]['2014':'2015']
test = df[final_cols]['2016':]

# %% [markdown]
# Как-то так.
#
# ## Моделька ##

# %%
def mape(y_true, y_pred):
    return np.mean(np.abs((y_pred-y_true)/y_true))

# %%
from sklearn.svm import SVR
model = SVR()
model.fit(train.values, train_target[:'2013'].values)
# Out:
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/data_sapiens/Anaconda/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVR(C=1.0, cache_size=200, coef0=0.0, degree=3, epsilon=0.1,
#     gamma='auto_deprecated', kernel='rbf', max_iter=-1, shrinking=True,
#     tol=0.001, verbose=False)

# %%
train_pred = model.predict(train.values)
val_pred = model.predict(val.values)
test_pred = model.predict(test.values)

# %%
print(f"TR performance: {mape(train_target[:'2013'].values, train_pred)}")
print(f"CV performance: {mape(train_target['2014':'2015'].values, val_pred)}")
# Out:
# TR performance: 0.1266195222403239
# CV performance: 0.2094885023912846

# %%
test_target['pet'] = test_pred
test_target.to_csv('../data/noidea.csv')

# %% [markdown]
# Короче, это нифига не работает, и ладно.

# %% [markdown]
# # Тупая фигня #

# %% [markdown]
# # Все это не работает, поэтому будем делать все иначе #

# %%
data = train_target.copy()
data['month'] = data.index.month

for i in range(1, 6):
    data['shifted_' + str(i)] = data['pet'].shift(i)
    
y = data['pet']
data.drop('pet', axis=1, inplace=True)
data['pet'] = y # так надо
y = y['2004-11-01':]

# %%
data.head(6)
# Out:
#             month  shifted_1  shifted_2  shifted_3  shifted_4  shifted_5  \
# date
# 2004-06-01      6        NaN        NaN        NaN        NaN        NaN
# 2004-07-01      7     961.25        NaN        NaN        NaN        NaN
# 2004-08-01      8     962.00     961.25        NaN        NaN        NaN
# 2004-09-01      9    1053.75     962.00     961.25        NaN        NaN
# 2004-10-01     10    1180.00    1053.75     962.00     961.25        NaN
# 2004-11-01     11    1240.00    1180.00    1053.75     962.00     961.25
#
#                 pet
# date
# 2004-06-01   961.25
# 2004-07-01   962.00
# 2004-08-01  1053.75
# 2004-09-01  1180.00
# 2004-10-01  1240.00
# 2004-11-01  1266.25

# %%
train = data['2004-11-01':]

test = test_target.copy()
test['month'] = test.index.month

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train.drop('pet', axis=1).values, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
full_data = pd.concat((train, test), axis=0, sort=False)
full_data.head()
# Out:
#             month  shifted_1  shifted_2  shifted_3  shifted_4  shifted_5  \
# date
# 2004-11-01     11    1240.00    1180.00    1053.75     962.00     961.25
# 2004-12-01     12    1266.25    1240.00    1180.00    1053.75     962.00
# 2005-01-01      1    1232.50    1266.25    1240.00    1180.00    1053.75
# 2005-02-01      2    1210.00    1232.50    1266.25    1240.00    1180.00
# 2005-03-01      3    1235.00    1210.00    1232.50    1266.25    1240.00
#
#                 pet
# date
# 2004-11-01  1266.25
# 2004-12-01  1232.50
# 2005-01-01  1210.00
# 2005-02-01  1235.00
# 2005-03-01  1271.25

# %%
for date in test_target.index:
    dt = date
    for i in range(1, 6):
        if dt.month == 1:
            dt = pd.datetime(dt.year - 1, 12, 1)
        else:
            dt = pd.datetime(dt.year, dt.month - 1, 1)
        full_data.loc[date, 'shifted_' + str(i)] = full_data.loc[dt]['pet']
    full_data.loc[date, 'pet'] = model.predict([full_data.drop('pet', axis=1).loc[date]])

# %%
full_data['2015-5-1':'2016-5-1']
# Out:
#             month    shifted_1    shifted_2    shifted_3    shifted_4  \
# date
# 2015-05-01      5  1015.000000   956.875000   919.166667   891.875000
# 2015-06-01      6  1098.500000  1015.000000   956.875000   919.166667
# 2015-07-01      7  1047.500000  1098.500000  1015.000000   956.875000
# 2015-08-01      8   979.500000  1047.500000  1098.500000  1015.000000
# 2015-09-01      9   908.125000   979.500000  1047.500000  1098.500000
# 2015-10-01     10   886.250000   908.125000   979.500000  1047.500000
# 2015-11-01     11   868.500000   886.250000   908.125000   979.500000
# 2015-12-01     12   853.750000   868.500000   886.250000   908.125000
# 2016-01-01      1   818.750000   853.750000   868.500000   886.250000
# 2016-02-01      2   839.713351   818.750000   853.750000   868.500000
# 2016-03-01      3   888.153071   839.713351   818.750000   853.750000
# 2016-04-01      4   932.507498   888.153071   839.713351   818.750000
# 2016-05-01      5   969.584602   932.507498   888.153071   839.713351
#
#               shifted_5          pet
# date
# 2015-05-01  1016.250000  1098.500000
# 2015-06-01   891.875000  1047.500000
# 2015-07-01   919.166667   979.500000
# 2015-08-01   956.875000   908.125000
# 2015-09-01  1015.000000   886.250000
# 2015-10-01  1098.500000   868.500000
# 2015-11-01  1047.500000   853.750000
# 2015-12-01   979.500000   818.750000
# 2016-01-01   908.125000   839.713351
# 2016-02-01   886.250000   888.153071
# 2016-03-01   868.500000   932.507498
# 2016-04-01   853.750000   969.584602
# 2016-05-01   818.750000   996.375402

# %%
full_data['pet'].plot()

# %%
test_target['pet'] = full_data['2016-1-1':]['pet']
test_target.to_csv('stupidtimeseries.csv')

# %% [markdown]
# ## Коротко: что мы сделали? ##
# Мы тупо использовали предсказания за последние пять месяцев как фичи, то есть сделали что-то вроде элементарного time series. И оно зашло!
