# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set()

# %%
import pathlib

DATA_DIR = pathlib.Path("../data/")
train_target = pd.read_csv(DATA_DIR.joinpath("pet_target_train.csv"), index_col="date", parse_dates=["date"])
test_target = pd.read_csv(DATA_DIR.joinpath("pet_test_timestamps.csv"), index_col="date", parse_dates=["date"])
daily = pd.read_csv(DATA_DIR.joinpath("pet_daily.csv"), index_col="date", parse_dates=["date"])
weekly = pd.read_csv(DATA_DIR.joinpath("pet_weekly.csv"), index_col="date", parse_dates=["date"])

# %% [markdown]
# ## Делаем датасет для прогнозирования временных рядов ##

# %%
data = train_target.copy()
data['month'] = data.index.month

for i in range(1, 6):
    data['shifted_' + str(i)] = data['pet'].shift(i)
    
y = data['pet']
data.drop('pet', axis=1, inplace=True)
data['pet'] = y # так надо

# %%
daily.index -= pd.Timedelta(days = 9)
daily.head()
# Out:
#             brent_close  brent_open  brent_max  brent_min  USDCNY_close  \
# date
# 2002-06-22        25.64       25.50      25.72      25.39        8.2770
# 2002-06-23        25.75       25.61      25.97      25.60        8.2769
# 2002-06-24        25.84       25.73      25.96      25.52        8.2768
# 2002-06-25        25.55       25.88      25.94      25.50        8.2767
# 2002-06-26        25.73       25.65      25.75      25.42        8.2766
#
#             USDCNY_open  USDCNY_max  USDCNY_min
# date
# 2002-06-22       8.2770      8.2770      8.2770
# 2002-06-23       8.2769      8.2769      8.2769
# 2002-06-24       8.2768      8.2768      8.2768
# 2002-06-25       8.2767      8.2767      8.2767
# 2002-06-26       8.2766      8.2766      8.2766

# %%
monthly = daily.resample('M').mean()
monthly.head()
# Out:
#             brent_close  brent_open  brent_max  brent_min  USDCNY_close  \
# date
# 2002-06-30    25.537143   25.595714  25.755714  25.305714      8.276757
# 2002-07-31    25.577273   25.538636  25.840000  25.256818      8.276795
# 2002-08-31    27.148000   27.040500  27.417500  26.794500      8.276815
# 2002-09-30    28.505000   28.577273  28.860455  28.249091      8.277064
# 2002-10-31    26.231905   26.396667  26.670000  26.005714      8.276957
#
#             USDCNY_open  USDCNY_max  USDCNY_min
# date
# 2002-06-30     8.276757    8.276757    8.276757
# 2002-07-31     8.276795    8.276795    8.276795
# 2002-08-31     8.276815    8.276815    8.276815
# 2002-09-30     8.277064    8.277064    8.277064
# 2002-10-31     8.276957    8.276957    8.276957

# %%
monthly.index += pd.Timedelta(days=1)
monthly.head()
# Out:
#             brent_close  brent_open  brent_max  brent_min  USDCNY_close  \
# date
# 2002-07-01    25.537143   25.595714  25.755714  25.305714      8.276757
# 2002-08-01    25.577273   25.538636  25.840000  25.256818      8.276795
# 2002-09-01    27.148000   27.040500  27.417500  26.794500      8.276815
# 2002-10-01    28.505000   28.577273  28.860455  28.249091      8.277064
# 2002-11-01    26.231905   26.396667  26.670000  26.005714      8.276957
#
#             USDCNY_open  USDCNY_max  USDCNY_min
# date
# 2002-07-01     8.276757    8.276757    8.276757
# 2002-08-01     8.276795    8.276795    8.276795
# 2002-09-01     8.276815    8.276815    8.276815
# 2002-10-01     8.277064    8.277064    8.277064
# 2002-11-01     8.276957    8.276957    8.276957

# %%
monthly.index += pd.offsets.MonthOffset(1)
monthly.head()
# Out:
#             brent_close  brent_open  brent_max  brent_min  USDCNY_close  \
# date
# 2002-08-01    25.537143   25.595714  25.755714  25.305714      8.276757
# 2002-09-01    25.577273   25.538636  25.840000  25.256818      8.276795
# 2002-10-01    27.148000   27.040500  27.417500  26.794500      8.276815
# 2002-11-01    28.505000   28.577273  28.860455  28.249091      8.277064
# 2002-12-01    26.231905   26.396667  26.670000  26.005714      8.276957
#
#             USDCNY_open  USDCNY_max  USDCNY_min
# date
# 2002-08-01     8.276757    8.276757    8.276757
# 2002-09-01     8.276795    8.276795    8.276795
# 2002-10-01     8.276815    8.276815    8.276815
# 2002-11-01     8.277064    8.277064    8.277064
# 2002-12-01     8.276957    8.276957    8.276957

# %%
y = y['2004-11-01':]
train = data['2004-11-01':]

test = test_target.copy()
test['month'] = test.index.month

full_data = pd.concat((train, test), axis=0, sort=False)
full_data.head()
# Out:
#             month  shifted_1  shifted_2  shifted_3  shifted_4  shifted_5  \
# date
# 2004-11-01     11    1240.00    1180.00    1053.75     962.00     961.25
# 2004-12-01     12    1266.25    1240.00    1180.00    1053.75     962.00
# 2005-01-01      1    1232.50    1266.25    1240.00    1180.00    1053.75
# 2005-02-01      2    1210.00    1232.50    1266.25    1240.00    1180.00
# 2005-03-01      3    1235.00    1210.00    1232.50    1266.25    1240.00
#
#                 pet
# date
# 2004-11-01  1266.25
# 2004-12-01  1232.50
# 2005-01-01  1210.00
# 2005-02-01  1235.00
# 2005-03-01  1271.25

# %%
full_data = full_data.join(monthly, on=full_data.index)
full_data.head()
# Out:
#             month  shifted_1  shifted_2  shifted_3  shifted_4  shifted_5  \
# date
# 2004-11-01     11    1240.00    1180.00    1053.75     962.00     961.25
# 2004-12-01     12    1266.25    1240.00    1180.00    1053.75     962.00
# 2005-01-01      1    1232.50    1266.25    1240.00    1180.00    1053.75
# 2005-02-01      2    1210.00    1232.50    1266.25    1240.00    1180.00
# 2005-03-01      3    1235.00    1210.00    1232.50    1266.25    1240.00
#
#                 pet  brent_close  brent_open  brent_max  brent_min  \
# date
# 2004-11-01  1266.25    44.814762   44.481429  45.204762  43.975238
# 2004-12-01  1232.50    48.799545   48.950000  49.641364  48.067273
# 2005-01-01  1210.00    42.598000   42.805000  43.579000  41.899000
# 2005-02-01  1235.00    40.898824   40.587059  41.494706  39.811176
# 2005-03-01  1271.25    44.796500   44.871000  45.425000  44.161000
#
#             USDCNY_close  USDCNY_open  USDCNY_max  USDCNY_min
# date
# 2004-11-01      8.276633     8.276633    8.276633    8.276633
# 2004-12-01      8.276500     8.276500    8.276500    8.276500
# 2005-01-01      8.276500     8.276500    8.276500    8.276500
# 2005-02-01      8.276500     8.276500    8.276500    8.276500
# 2005-03-01      8.276500     8.276500    8.276500    8.276500

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(full_data[:'2015'].drop('pet', axis=1).values, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
full_data['2015-5-1':'2016-5-1']
# Out:
#             month  shifted_1  shifted_2    shifted_3    shifted_4  \
# date
# 2015-05-01      5   1015.000    956.875   919.166667   891.875000
# 2015-06-01      6   1098.500   1015.000   956.875000   919.166667
# 2015-07-01      7   1047.500   1098.500  1015.000000   956.875000
# 2015-08-01      8    979.500   1047.500  1098.500000  1015.000000
# 2015-09-01      9    908.125    979.500  1047.500000  1098.500000
# 2015-10-01     10    886.250    908.125   979.500000  1047.500000
# 2015-11-01     11    868.500    886.250   908.125000   979.500000
# 2015-12-01     12    853.750    868.500   886.250000   908.125000
# 2016-01-01      1    818.750    853.750   868.500000   886.250000
# 2016-02-01      2        NaN        NaN          NaN          NaN
# 2016-03-01      3        NaN        NaN          NaN          NaN
# 2016-04-01      4        NaN        NaN          NaN          NaN
# 2016-05-01      5        NaN        NaN          NaN          NaN
#
#               shifted_5       pet  brent_close  brent_open  brent_max  \
# date
# 2015-05-01  1016.250000  1098.500    56.099545   56.146818  57.353636
# 2015-06-01   891.875000  1047.500    63.756500   63.476000  64.696000
# 2015-07-01   919.166667   979.500    64.802381   64.861905  65.781429
# 2015-08-01   956.875000   908.125    62.224091   62.464091  63.283182
# 2015-09-01  1015.000000   886.250    54.402632   54.796316  55.403684
# 2015-10-01  1098.500000   868.500    48.170909   48.163636  49.390000
# 2015-11-01  1047.500000   853.750    49.025000   48.885500  49.963000
# 2015-12-01   979.500000   818.750    48.615238   48.979524  49.594762
# 2016-01-01   908.125000       NaN    43.881429   44.371429  45.056667
# 2016-02-01          NaN       NaN    36.784737   37.226316  37.790000
# 2016-03-01          NaN       NaN    31.693000   31.652000  32.872000
# 2016-04-01          NaN       NaN    35.306667   34.933810  36.185714
# 2016-05-01          NaN       NaN    39.987143   40.022381  40.729524
#
#             brent_min  USDCNY_close  USDCNY_open  USDCNY_max  USDCNY_min
# date
# 2015-05-01  54.829545      6.220241     6.222555    6.226791    6.214541
# 2015-06-01  62.682000      6.203945     6.202765    6.208010    6.199125
# 2015-07-01  63.844762      6.202767     6.202238    6.205367    6.199733
# 2015-08-01  61.423636      6.207514     6.206809    6.209441    6.205427
# 2015-09-01  53.791053      6.209411     6.209353    6.209884    6.208153
# 2015-10-01  46.976364      6.382095     6.380668    6.394668    6.373023
# 2015-11-01  48.057500      6.364375     6.365950    6.367950    6.360955
# 2015-12-01  48.038571      6.347029     6.345533    6.353605    6.339757
# 2016-01-01  43.347619      6.391110     6.387719    6.392705    6.384762
# 2016-02-01  36.188421      6.496158     6.488621    6.499126    6.486289
# 2016-03-01  30.631500      6.577600     6.577870    6.582175    6.574330
# 2016-04-01  34.179048      6.532843     6.534595    6.539024    6.528167
# 2016-05-01  39.257143      6.488314     6.491848    6.499095    6.482576

# %%
for date in test_target.index:
    dt = date
    for i in range(1, 6):
        if dt.month == 1:
            dt = pd.datetime(dt.year - 1, 12, 1)
        else:
            dt = pd.datetime(dt.year, dt.month - 1, 1)
        full_data.loc[date, 'shifted_' + str(i)] = full_data.loc[dt]['pet']
    full_data.loc[date, 'pet'] = model.predict([full_data.drop('pet', axis=1).loc[date]])

# %%
full_data['pet'].plot()

# %% [markdown]
# Окей, этот жуткий рост не работает. Нужно что-то иное.

# %% [markdown]
# ## А давайте короче интерпретировать данные нам фичи тоже как временные ряды? ##

# %%
daily.head()
# Out:
#             brent_close  brent_open  brent_max  brent_min  USDCNY_close  \
# date
# 2002-07-01        25.64       25.50      25.72      25.39        8.2770
# 2002-07-02        25.75       25.61      25.97      25.60        8.2769
# 2002-07-03        25.84       25.73      25.96      25.52        8.2768
# 2002-07-04        25.55       25.88      25.94      25.50        8.2767
# 2002-07-05        25.73       25.65      25.75      25.42        8.2766
#
#             USDCNY_open  USDCNY_max  USDCNY_min
# date
# 2002-07-01       8.2770      8.2770      8.2770
# 2002-07-02       8.2769      8.2769      8.2769
# 2002-07-03       8.2768      8.2768      8.2768
# 2002-07-04       8.2767      8.2767      8.2767
# 2002-07-05       8.2766      8.2766      8.2766

# %%
daily2 = daily.resample('D').ffill()

# %% [markdown]
# В общем, из всех brent и USDCNY можно брать всего по одному, например, _close.

# %%
data = train_target.copy()
data['month'] = data.index.month

for i in range(1, 6):
    data['shifted_' + str(i)] = data['pet'].shift(i)
    
y = data['pet']
data.drop('pet', axis=1, inplace=True)
data['pet'] = y # так надо

# %%
data.head()
# Out:
#             month  shifted_1  shifted_2  shifted_3  shifted_4  shifted_5  \
# date
# 2004-06-01      6        NaN        NaN        NaN        NaN        NaN
# 2004-07-01      7     961.25        NaN        NaN        NaN        NaN
# 2004-08-01      8     962.00     961.25        NaN        NaN        NaN
# 2004-09-01      9    1053.75     962.00     961.25        NaN        NaN
# 2004-10-01     10    1180.00    1053.75     962.00     961.25        NaN
#
#                 pet
# date
# 2004-06-01   961.25
# 2004-07-01   962.00
# 2004-08-01  1053.75
# 2004-09-01  1180.00
# 2004-10-01  1240.00

# %%
#y = y['2004-11-01':]
#train = data['2004-11-01':]

test = test_target.copy()
test['month'] = test.index.month

full_data = pd.concat((data, test), axis=0, sort=False)
full_data.head()
# Out:
#             month  shifted_1  shifted_2  shifted_3  shifted_4  shifted_5  \
# date
# 2004-06-01      6        NaN        NaN        NaN        NaN        NaN
# 2004-07-01      7     961.25        NaN        NaN        NaN        NaN
# 2004-08-01      8     962.00     961.25        NaN        NaN        NaN
# 2004-09-01      9    1053.75     962.00     961.25        NaN        NaN
# 2004-10-01     10    1180.00    1053.75     962.00     961.25        NaN
#
#                 pet
# date
# 2004-06-01   961.25
# 2004-07-01   962.00
# 2004-08-01  1053.75
# 2004-09-01  1180.00
# 2004-10-01  1240.00

# %%
for i in range(10):
    full_data['brent_' + str(i + 1)] = daily2.loc[full_data.index - pd.offsets.MonthOffset(1)
                                                    + pd.Timedelta(days=i)]['brent_close'].values
    full_data['USDCNY_' + str(i + 1)] = daily2.loc[full_data.index - pd.offsets.MonthOffset(1)
                                                    + pd.Timedelta(days=i)]['USDCNY_close'].values
full_data.head(10)
# Out:
#             month  shifted_1  shifted_2  shifted_3  shifted_4  shifted_5  \
# date
# 2004-06-01      6        NaN        NaN        NaN        NaN        NaN
# 2004-07-01      7     961.25        NaN        NaN        NaN        NaN
# 2004-08-01      8     962.00     961.25        NaN        NaN        NaN
# 2004-09-01      9    1053.75     962.00     961.25        NaN        NaN
# 2004-10-01     10    1180.00    1053.75     962.00     961.25        NaN
# 2004-11-01     11    1240.00    1180.00    1053.75     962.00     961.25
# 2004-12-01     12    1266.25    1240.00    1180.00    1053.75     962.00
# 2005-01-01      1    1232.50    1266.25    1240.00    1180.00    1053.75
# 2005-02-01      2    1210.00    1232.50    1266.25    1240.00    1180.00
# 2005-03-01      3    1235.00    1210.00    1232.50    1266.25    1240.00
#
#                 pet  brent_1  USDCNY_1  brent_2  ...  brent_6  USDCNY_6  \
# date                                             ...
# 2004-06-01   961.25    34.48    8.2771    34.48  ...    36.53    8.2771
# 2004-07-01   962.00    39.08    8.2767    39.08  ...    35.67    8.2767
# 2004-08-01  1053.75    36.07    8.2767    35.92  ...    37.18    8.2768
# 2004-09-01  1180.00    40.03    8.2769    39.97  ...    40.63    8.2769
# 2004-10-01  1240.00    41.47    8.2766    41.57  ...    40.62    8.2766
# 2004-11-01  1266.25    46.62    8.2766    46.62  ...    47.99    8.2766
# 2004-12-01  1232.50    47.06    8.2765    46.55  ...    46.42    8.2765
# 2005-01-01  1210.00    42.31    8.2765    40.15  ...    39.65    8.2765
# 2005-02-01  1235.00    40.46    8.2765    40.46  ...    42.85    8.2765
# 2005-03-01  1271.25    44.82    8.2765    44.01  ...    43.89    8.2765
#
#             brent_7  USDCNY_7  brent_8  USDCNY_8  brent_9  USDCNY_9  brent_10  \
# date
# 2004-06-01    37.00    8.2771    37.00    8.2771    37.00    8.2771     35.97
# 2004-07-01    35.96    8.2767    35.05    8.2767    35.29    8.2767     35.74
# 2004-08-01    36.61    8.2768    37.77    8.2769    37.05    8.2769     37.05
# 2004-09-01    40.63    8.2769    40.63    8.2769    40.63    8.2769     41.28
# 2004-10-01    40.76    8.2767    40.39    8.2767    42.22    8.2768     40.20
# 2004-11-01    48.90    8.2766    49.71    8.2768    49.71    8.2768     49.71
# 2004-12-01    46.42    8.2765    45.92    8.2765    43.71    8.2765     44.75
# 2005-01-01    38.27    8.2765    38.69    8.2765    39.67    8.2765     37.38
# 2005-02-01    43.18    8.2765    43.18    8.2765    43.18    8.2765     42.92
# 2005-03-01    43.04    8.2765    43.04    8.2765    43.04    8.2765     43.04
#
#             USDCNY_10
# date
# 2004-06-01     8.2769
# 2004-07-01     8.2768
# 2004-08-01     8.2769
# 2004-09-01     8.2770
# 2004-10-01     8.2766
# 2004-11-01     8.2768
# 2004-12-01     8.2765
# 2005-01-01     8.2765
# 2005-02-01     8.2765
# 2005-03-01     8.2765
#
# [10 rows x 27 columns]

# %%
train = full_data['2004-11-01':'2015']
y = y['2004-11-01':]

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(train.drop('pet', axis=1).values, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
for date in test_target.index:
    dt = date
    for i in range(1, 6):
        if dt.month == 1:
            dt = pd.datetime(dt.year - 1, 12, 1)
        else:
            dt = pd.datetime(dt.year, dt.month - 1, 1)
        full_data.loc[date, 'shifted_' + str(i)] = full_data.loc[dt]['pet']
    full_data.loc[date, 'pet'] = model.predict([full_data.drop('pet', axis=1).loc[date]])

# %%
full_data['pet'].plot()

# %%
test_target['pet'] = full_data['2016-1-1':]['pet']
test_target.to_csv('../submissions/notsostupidtimeseries.csv')
